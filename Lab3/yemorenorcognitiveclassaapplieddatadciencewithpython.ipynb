# %% [markdown]
# <a href="https://colab.research.google.com/github/yemorenor/MetNumUN2022II/blob/main/Lab3/yemorenorcognitiveclassaapplieddatadciencewithpython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **LAB 3:**
#
#
# IBM: PY0101EN
#
# Python for Data Science

# %% [markdown]
# [Post in Linkedin](https://www.linkedin.com/feed/update/urn:li:ugcPost:6976195219931222016/)

# %% [markdown]
# ![CERTIFICADO1.PNG](data:image/png;base64,...)

# %% [markdown]
# IBM: DA0101EN
#
# Data Analysis with Python
#
# [post in linkedin](https://www.linkedin.com/posts/yeray-dario-moreno-rangel-31717b1ab_ibmda0101en-dataanalysiswithpython-activity-6976202144391557121-bWup?utm_source=share&utm_medium=member_desktop)

# %% [markdown]
# ![CERTIFICADO2.PNG](data:image/png;base64,...)

# %% [markdown]
# IBM: DV0101EN
#
# Data Visualization with Python
#
# [post in linkedin](https://www.linkedin.com/posts/yeray-dario-moreno-rangel-31717b1ab_ibmdv0101en-data-visualization-with-python-activity-6976207130483695616-H6iv?utm_source=share&utm_medium=member_desktop)

# %% [markdown]
# ![CERTIFICADO3.PNG](data:image/png;base64,...)
