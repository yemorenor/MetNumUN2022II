# %% [markdown]
# <a href="https://colab.research.google.com/github/yemorenor/MetNumUN2022II/blob/main/Lab5/group31AlgorithmicToolboxWeek1Quadratic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Laboratorio 5:

# %% [markdown]
# ![imagen_2022-11-16_231908007.png](data:image/png;base64,...)
